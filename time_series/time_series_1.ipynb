# %%
from vega_datasets import data
import numpy as np
df = data.sf_temps()
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import math

# %% [markdown]
# Resample by the day and take the average temperature. Visualize the average temperature over time.

# %%
df = df.set_index('date')

# %%
df.describe()
# Out:
#               temp
# count  8759.000000
# mean     56.924112
# std       6.107079
# min      45.600000
# 25%      52.300000
# 50%      56.500000
# 75%      60.700000
# max      72.200000

# %%
df.isnull().sum()
# Out:
# temp    0
# dtype: int64

# %%
df.asfreq('D')
# Out:
#             temp
# date
# 2010-01-01  47.8
# 2010-01-02  47.9
# 2010-01-03  48.0
# 2010-01-04  48.1
# 2010-01-05  48.0
# 2010-01-06  48.1
# 2010-01-07  48.1
# 2010-01-08  48.0
# 2010-01-09  48.0
# 2010-01-10  48.1
# 2010-01-11  48.1
# 2010-01-12  48.2
# 2010-01-13  48.2
# 2010-01-14  48.4
# 2010-01-15  48.4
# 2010-01-16  48.4
# 2010-01-17  48.4
# 2010-01-18  48.4
# 2010-01-19  48.5
# 2010-01-20  48.6
# 2010-01-21  48.6
# 2010-01-22  48.7
# 2010-01-23  48.8
# 2010-01-24  48.8
# 2010-01-25  48.8
# 2010-01-26  48.9
# 2010-01-27  48.9
# 2010-01-28  49.0
# 2010-01-29  49.2
# 2010-01-30  49.3
# ...          ...
# 2010-12-02  50.3
# 2010-12-03  50.3
# 2010-12-04  50.3
# 2010-12-05  50.2
# 2010-12-06  50.2
# 2010-12-07  50.2
# 2010-12-08  50.1
# 2010-12-09  50.0
# 2010-12-10  50.0
# 2010-12-11  49.9
# 2010-12-12  49.8
# 2010-12-13  49.7
# 2010-12-14  49.5
# 2010-12-15  49.3
# 2010-12-16  49.0
# 2010-12-17  48.7
# 2010-12-18  48.5
# 2010-12-19  48.2
# 2010-12-20  48.1
# 2010-12-21  48.0
# 2010-12-22  47.8
# 2010-12-23  47.7
# 2010-12-24  47.7
# 2010-12-25  47.7
# 2010-12-26  47.6
# 2010-12-27  47.6
# 2010-12-28  47.6
# 2010-12-29  47.6
# 2010-12-30  47.5
# 2010-12-31  47.7
#
# [365 rows x 1 columns]

# %%
df.resample('D').mean()
# Out:
#                  temp
# date
# 2010-01-01  49.170833
# 2010-01-02  49.304167
# 2010-01-03  49.391667
# 2010-01-04  49.445833
# 2010-01-05  49.491667
# 2010-01-06  49.529167
# 2010-01-07  49.466667
# 2010-01-08  49.475000
# 2010-01-09  49.537500
# 2010-01-10  49.604167
# 2010-01-11  49.675000
# 2010-01-12  49.733333
# 2010-01-13  49.762500
# 2010-01-14  49.866667
# 2010-01-15  49.908333
# 2010-01-16  49.908333
# 2010-01-17  49.950000
# 2010-01-18  49.962500
# 2010-01-19  50.062500
# 2010-01-20  50.137500
# 2010-01-21  50.170833
# 2010-01-22  50.308333
# 2010-01-23  50.354167
# 2010-01-24  50.350000
# 2010-01-25  50.404167
# 2010-01-26  50.495833
# 2010-01-27  50.583333
# 2010-01-28  50.720833
# 2010-01-29  50.808333
# 2010-01-30  50.891667
# ...               ...
# 2010-12-02  52.391667
# 2010-12-03  52.337500
# 2010-12-04  52.279167
# 2010-12-05  52.183333
# 2010-12-06  52.104167
# 2010-12-07  51.987500
# 2010-12-08  51.875000
# 2010-12-09  51.737500
# 2010-12-10  51.579167
# 2010-12-11  51.445833
# 2010-12-12  51.320833
# 2010-12-13  51.125000
# 2010-12-14  50.875000
# 2010-12-15  50.608333
# 2010-12-16  50.325000
# 2010-12-17  50.041667
# 2010-12-18  49.779167
# 2010-12-19  49.591667
# 2010-12-20  49.441667
# 2010-12-21  49.316667
# 2010-12-22  49.175000
# 2010-12-23  49.137500
# 2010-12-24  49.125000
# 2010-12-25  49.112500
# 2010-12-26  49.025000
# 2010-12-27  48.991667
# 2010-12-28  49.000000
# 2010-12-29  49.012500
# 2010-12-30  49.012500
# 2010-12-31  49.116667
#
# [365 rows x 1 columns]

# %% [markdown]
# Write the code necessary to visualize the minimum temperature over time.

# %%
df.plot()
plt.show()

# %%
df.resample("D").min().plot()
plt.show()

# %% [markdown]
# Write the code necessary to visualize the maximum temperature over time.

# %%
df.resample("D").max()
# Out:
#             temp
# date
# 2010-01-01  53.3
# 2010-01-02  53.4
# 2010-01-03  53.5
# 2010-01-04  53.6
# 2010-01-05  53.8
# 2010-01-06  53.8
# 2010-01-07  53.8
# 2010-01-08  53.9
# 2010-01-09  54.0
# 2010-01-10  54.1
# 2010-01-11  54.2
# 2010-01-12  54.3
# 2010-01-13  54.4
# 2010-01-14  54.5
# 2010-01-15  54.6
# 2010-01-16  54.6
# 2010-01-17  54.7
# 2010-01-18  54.7
# 2010-01-19  54.8
# 2010-01-20  54.9
# 2010-01-21  54.9
# 2010-01-22  55.2
# 2010-01-23  55.3
# 2010-01-24  55.3
# 2010-01-25  55.4
# 2010-01-26  55.5
# 2010-01-27  55.6
# 2010-01-28  55.8
# 2010-01-29  56.0
# 2010-01-30  56.1
# ...          ...
# 2010-12-02  57.4
# 2010-12-03  57.3
# 2010-12-04  57.2
# 2010-12-05  57.0
# 2010-12-06  56.8
# 2010-12-07  56.7
# 2010-12-08  56.5
# 2010-12-09  56.3
# 2010-12-10  56.1
# 2010-12-11  55.9
# 2010-12-12  55.8
# 2010-12-13  55.5
# 2010-12-14  55.2
# 2010-12-15  54.9
# 2010-12-16  54.7
# 2010-12-17  54.4
# 2010-12-18  54.2
# 2010-12-19  54.0
# 2010-12-20  53.8
# 2010-12-21  53.6
# 2010-12-22  53.5
# 2010-12-23  53.4
# 2010-12-24  53.3
# 2010-12-25  53.3
# 2010-12-26  53.2
# 2010-12-27  53.2
# 2010-12-28  53.2
# 2010-12-29  53.2
# 2010-12-30  53.2
# 2010-12-31  53.2
#
# [365 rows x 1 columns]

# %%
df.resample("D").max().plot()
plt.show()

# %% [markdown]
# Which month is the coldest, on average?

# %%
df.resample("M").min().sort_values(by = 'temp').head(1)
# Out:
#             temp
# date
# 2010-12-31  45.6

# %%
df.resample("M").min().plot()
plt.show()

# %% [markdown]
# #### Which month has the highest average temperature?

# %%
df.resample("M").mean().sort_values(by = 'temp').head(1)
# Out:
#                 temp
# date
# 2010-01-31  49.98414

# %%
df.resample("M").mean().plot()
plt.show()

# %% [markdown]
# #### Resample by the day and calculate the min and max temp for the day (Hint: .agg(['min', 'max'])). Use this resampled dataframe to calculate the change in temperature for the day. Which month has the highest daily temperature variability?

# %%
min_max_temps = df.resample('D').agg(['min', 'max'])
min_max_temps.head()
# Out:
#             temp
#              min   max
# date
# 2010-01-01  45.8  53.3
# 2010-01-02  46.0  53.4
# 2010-01-03  46.1  53.5
# 2010-01-04  46.1  53.6
# 2010-01-05  46.1  53.8

# %%
temp_diff = min_max_temps.temp['max'] - min_max_temps.temp['min']
# tri_montly_cofee_consumption = df.coffee_consumption.resample('3M').agg(['min', 'max'])
# tri_montly_cofee_consumption['max'] - tri_montly_cofee_consumption['min']

# %%
min_max_temps.plot()
plt.show()

# %% [markdown]
# #### Bonus: Visualize the daily min, average, and max temperature over time on a single line plot, i.e. the min, average, and maximum temperature should be 3 seperate lines.

# %%
min_avg_max_temps = df.temp.resample('D').agg(['min', 'mean', 'max'])
min_avg_max_temps
# Out:
#              min       mean   max
# date
# 2010-01-01  45.8  49.170833  53.3
# 2010-01-02  46.0  49.304167  53.4
# 2010-01-03  46.1  49.391667  53.5
# 2010-01-04  46.1  49.445833  53.6
# 2010-01-05  46.1  49.491667  53.8
# 2010-01-06  46.1  49.529167  53.8
# 2010-01-07  46.0  49.466667  53.8
# 2010-01-08  46.0  49.475000  53.9
# 2010-01-09  46.0  49.537500  54.0
# 2010-01-10  46.1  49.604167  54.1
# 2010-01-11  46.1  49.675000  54.2
# 2010-01-12  46.2  49.733333  54.3
# 2010-01-13  46.1  49.762500  54.4
# 2010-01-14  46.2  49.866667  54.5
# 2010-01-15  46.2  49.908333  54.6
# 2010-01-16  46.2  49.908333  54.6
# 2010-01-17  46.2  49.950000  54.7
# 2010-01-18  46.2  49.962500  54.7
# 2010-01-19  46.4  50.062500  54.8
# 2010-01-20  46.4  50.137500  54.9
# 2010-01-21  46.5  50.170833  54.9
# 2010-01-22  46.6  50.308333  55.2
# 2010-01-23  46.6  50.354167  55.3
# 2010-01-24  46.5  50.350000  55.3
# 2010-01-25  46.5  50.404167  55.4
# 2010-01-26  46.6  50.495833  55.5
# 2010-01-27  46.6  50.583333  55.6
# 2010-01-28  46.7  50.720833  55.8
# 2010-01-29  46.7  50.808333  56.0
# 2010-01-30  46.8  50.891667  56.1
# ...          ...        ...   ...
# 2010-12-02  48.6  52.391667  57.4
# 2010-12-03  48.6  52.337500  57.3
# 2010-12-04  48.6  52.279167  57.2
# 2010-12-05  48.5  52.183333  57.0
# 2010-12-06  48.5  52.104167  56.8
# 2010-12-07  48.4  51.987500  56.7
# 2010-12-08  48.3  51.875000  56.5
# 2010-12-09  48.3  51.737500  56.3
# 2010-12-10  48.1  51.579167  56.1
# 2010-12-11  48.0  51.445833  55.9
# 2010-12-12  47.9  51.320833  55.8
# 2010-12-13  47.7  51.125000  55.5
# 2010-12-14  47.5  50.875000  55.2
# 2010-12-15  47.3  50.608333  54.9
# 2010-12-16  46.9  50.325000  54.7
# 2010-12-17  46.7  50.041667  54.4
# 2010-12-18  46.4  49.779167  54.2
# 2010-12-19  46.1  49.591667  54.0
# 2010-12-20  46.0  49.441667  53.8
# 2010-12-21  45.9  49.316667  53.6
# 2010-12-22  45.8  49.175000  53.5
# 2010-12-23  45.7  49.137500  53.4
# 2010-12-24  45.7  49.125000  53.3
# 2010-12-25  45.8  49.112500  53.3
# 2010-12-26  45.7  49.025000  53.2
# 2010-12-27  45.6  48.991667  53.2
# 2010-12-28  45.6  49.000000  53.2
# 2010-12-29  45.6  49.012500  53.2
# 2010-12-30  45.6  49.012500  53.2
# 2010-12-31  45.8  49.116667  53.2
#
# [365 rows x 3 columns]

# %%
min_avg_max_temps.plot()
plt.show()

# %%
from vega_datasets import data
df = data.seattle_weather()
df.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1461, step=1)

# %% [markdown]
# #### Which year and month combination has the highest amount of precipitation?

# %%
df.groupby([df.date.dt.year, df.date.dt.month]).sum().precipitation.idxmax()
# Out:
# (2015, 12)

# %% [markdown]
# #### Visualize the amount of monthly precipitation over time.

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.sort_values('date').set_index('date')
df.head(1)
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle

# %%
df.precipitation.resample("M").sum().plot()
plt.show()

# %% [markdown]
# #### Visualize the amount of wind over time. Choose a time interval you think is appropriate.

# %%
df.wind.resample("M").sum().plot()
plt.show()

# %% [markdown]
# #### Which year-month combination is the windiest?

# %%
df.groupby([df.index.year, df.index.month]).sum().wind.idxmax()
# Out:
# (2015, 12)

# %% [markdown]
# #### What's the sunniest year? (Hint: which day has the highest number of days where weather == sun?)

# %%
df2 = df.assign(sunny = df.weather == 'sun')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2012-01-01 to 2015-12-31
# Data columns (total 6 columns):
# precipitation    1461 non-null float64
# temp_max         1461 non-null float64
# temp_min         1461 non-null float64
# wind             1461 non-null float64
# weather          1461 non-null object
# sunny            1461 non-null bool
# dtypes: bool(1), float64(4), object(1)
# memory usage: 69.9+ KB

# %%
df2.resample('Y').sunny.sum()
# Out:
# date
# 2012-12-31    118.0
# 2013-12-31    205.0
# 2014-12-31    211.0
# 2015-12-31    180.0
# Freq: A-DEC, Name: sunny, dtype: float64

# %% [markdown]
# #### In which month does it rain the most?

# %%
df3 = df.assign(rainy = df.weather == 'rain')
df3.head()
# Out:
#             precipitation  temp_max  temp_min  wind  weather  rainy
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle  False
# 2012-01-02           10.9      10.6       2.8   4.5     rain   True
# 2012-01-03            0.8      11.7       7.2   2.3     rain   True
# 2012-01-04           20.3      12.2       5.6   4.7     rain   True
# 2012-01-05            1.3       8.9       2.8   6.1     rain   True

# %%
df3.resample('Y').rainy.sum()
# Out:
# date
# 2012-12-31    191.0
# 2013-12-31     60.0
# 2014-12-31      3.0
# 2015-12-31      5.0
# Freq: A-DEC, Name: rainy, dtype: float64

# %% [markdown]
# #### Which month has the most number of days with a non-zero amount of precipitation?

# %%
df3.weather.value_counts()
# Out:
# sun        714
# fog        411
# rain       259
# drizzle     54
# snow        23
# Name: weather, dtype: int64

# %%
df3['precipitation'] = np.where((df3.weather == 'snow') | (df3.weather == 'rain') | (df3.weather == 'drizzle') ,1,0)

# %%
df3.resample('M').precipitation.sum().max()
# Out:
# 30

# %%
df3.groupby([df3.index.year, df3.index.month]).sum().precipitation.idxmax()
# Out:
# (2012, 12)

# %%
df3.precipitation.resample('M').sum().plot()
plt.show()

# %%
df4 = data.flights_20k()

# %% [markdown]
# Convert any negative delays to 0.

# %%
df4['non_neg_delay'] = np.where((df4.delay < 0), 0, df4.delay)

# %% [markdown]
# Which hour of the day has the highest average delay?

# %%
df4['date'] = pd.to_datetime(df4['date'])

# %%
df4 = df4.sort_values('date').set_index('date')

# %%
df4['hour'] = df4.index.hour
df4.head()
# Out:
#                      delay destination  distance origin  non_neg_delay  hour
# date
# 2001-01-01 00:01:00     14         MDW       405    MCI             14     0
# 2001-01-01 06:20:00      0         MCI       491    BNA              0     6
# 2001-01-01 06:30:00     -8         STL       251    MDW              0     6
# 2001-01-01 07:00:00    -10         ONT       361    OAK              0     7
# 2001-01-01 07:00:00      0         HOU       303    MSY              0     7

# %%
df4.groupby('hour').delay.mean().sort_values(ascending = False)
# Out:
# hour
# 3     302.500000
# 1     170.000000
# 0     127.916667
# 23     64.153846
# 22     31.200542
# 21     19.565832
# 20     15.605333
# 19     13.979508
# 18     11.584518
# 16     11.343851
# 15     10.841933
# 17     10.811625
# 13      8.819185
# 14      7.850689
# 12      6.218967
# 11      3.916328
# 10      2.183709
# 9       0.789649
# 8      -0.078067
# 6      -1.026749
# 7      -1.121298
# 5      -4.837838
# Name: delay, dtype: float64

# %% [markdown]
# Does the day of the week make a difference in the delay amount?

# %%
df4['day-of-week'] = df4.index.strftime('%w' '%a')
df4.head()
# Out:
#                      delay destination  distance origin  non_neg_delay  hour  \
# date
# 2001-01-01 00:01:00     14         MDW       405    MCI             14     0
# 2001-01-01 06:20:00      0         MCI       491    BNA              0     6
# 2001-01-01 06:30:00     -8         STL       251    MDW              0     6
# 2001-01-01 07:00:00    -10         ONT       361    OAK              0     7
# 2001-01-01 07:00:00      0         HOU       303    MSY              0     7
#
#                     day-of-week
# date
# 2001-01-01 00:01:00        1Mon
# 2001-01-01 06:20:00        1Mon
# 2001-01-01 06:30:00        1Mon
# 2001-01-01 07:00:00        1Mon
# 2001-01-01 07:00:00        1Mon

# %%
df4.groupby('day-of-week').delay.mean().sort_values(ascending = False)
# Out:
# day-of-week
# 5Fri    15.594452
# 4Thu    10.245766
# 3Wed     8.161416
# 0Sun     7.255164
# 2Tue     6.198981
# 6Sat     4.667520
# 1Mon     3.595973
# Name: delay, dtype: float64

# %% [markdown]
# Does the month make a difference in the delay amount?

# %%
df4['month'] = df4.index.strftime('%m %b')
df4.head()
# Out:
#                      delay destination  distance origin  non_neg_delay  hour  \
# date
# 2001-01-01 00:01:00     14         MDW       405    MCI             14     0
# 2001-01-01 06:20:00      0         MCI       491    BNA              0     6
# 2001-01-01 06:30:00     -8         STL       251    MDW              0     6
# 2001-01-01 07:00:00    -10         ONT       361    OAK              0     7
# 2001-01-01 07:00:00      0         HOU       303    MSY              0     7
#
#                     day-of-week   month
# date
# 2001-01-01 00:01:00        1Mon  01 Jan
# 2001-01-01 06:20:00        1Mon  01 Jan
# 2001-01-01 06:30:00        1Mon  01 Jan
# 2001-01-01 07:00:00        1Mon  01 Jan
# 2001-01-01 07:00:00        1Mon  01 Jan

# %%
df4.groupby('month').delay.mean().plot.bar(figsize=(9, 5), color='red', edgecolor='black')

mu = df4.delay.mean()
se = 2.58 * (df4.delay.std()/math.sqrt(df4.shape[0]))
ub, lb = mu + se, mu - se

plt.hlines(mu, -.5, 2.5, ls = '--')
plt.hlines([lb, ub], -.5, 2.5,ls =':')
plt.xticks(rotation = 0)

plt.show()

# %%
from vega_datasets import data
iowa = data.iowa_electricity()
iowa.head()
# Out:
#         year        source  net_generation
# 0 2001-01-01  Fossil Fuels           35361
# 1 2002-01-01  Fossil Fuels           35991
# 2 2003-01-01  Fossil Fuels           36234
# 3 2004-01-01  Fossil Fuels           36205
# 4 2005-01-01  Fossil Fuels           36883

# %%
iowa.shape
# Out:
# (51, 3)

# %%
iowa.year.value_counts()
# Out:
# 2009-01-01    3
# 2001-01-01    3
# 2002-01-01    3
# 2008-01-01    3
# 2005-01-01    3
# 2011-01-01    3
# 2014-01-01    3
# 2004-01-01    3
# 2017-01-01    3
# 2012-01-01    3
# 2007-01-01    3
# 2010-01-01    3
# 2016-01-01    3
# 2013-01-01    3
# 2003-01-01    3
# 2006-01-01    3
# 2015-01-01    3
# Name: year, dtype: int64

# %%
sns.lineplot(data=iowa.reset_index(), x='year', y='net_generation', hue='source')
plt.show()

# %%
iowa.pivot_table('net_generation', 'year', 'source')
# Out:
# source      Fossil Fuels  Nuclear Energy  Renewables
# year
# 2001-01-01         35361            3853        1437
# 2002-01-01         35991            4574        1963
# 2003-01-01         36234            3988        1885
# 2004-01-01         36205            4929        2102
# 2005-01-01         36883            4538        2724
# 2006-01-01         37014            5095        3364
# 2007-01-01         41389            4519        3870
# 2008-01-01         42734            5282        5070
# 2009-01-01         38620            4679        8560
# 2010-01-01         42750            4451       10308
# 2011-01-01         39361            5215       11795
# 2012-01-01         37379            4347       14949
# 2013-01-01         34873            5321       16476
# 2014-01-01         35250            4152       17452
# 2015-01-01         32319            5243       19091
# 2016-01-01         28437            4703       21241
# 2017-01-01         29329            5214       21933

# %%
iowa.pivot_table('net_generation', 'year', 'source').plot()

# %% [markdown]
# For each row, calculate the percentage of the year's total that energy source provided.

# %%
iowa = iowa.sort_values('year').set_index('year')
iowa.head()
# Out:
#                     source  net_generation
# year
# 2001-01-01    Fossil Fuels           35361
# 2001-01-01  Nuclear Energy            3853
# 2001-01-01      Renewables            1437
# 2002-01-01    Fossil Fuels           35991
# 2002-01-01  Nuclear Energy            4574

# %%
iowa['just_year'] = iowa.index.strftime('%Y')
iowa.head()
# Out:
#                     source  net_generation just_year
# year
# 2001-01-01    Fossil Fuels           35361      2001
# 2001-01-01  Nuclear Energy            3853      2001
# 2001-01-01      Renewables            1437      2001
# 2002-01-01    Fossil Fuels           35991      2002
# 2002-01-01  Nuclear Energy            4574      2002

# %%
iowa.groupby(['just_year', 'source']).mean()/iowa.net_generation.sum()
# Out:
#                           net_generation
# just_year source
# 2001      Fossil Fuels          0.040906
#           Nuclear Energy        0.004457
#           Renewables            0.001662
# 2002      Fossil Fuels          0.041634
#           Nuclear Energy        0.005291
#           Renewables            0.002271
# 2003      Fossil Fuels          0.041916
#           Nuclear Energy        0.004613
#           Renewables            0.002181
# 2004      Fossil Fuels          0.041882
#           Nuclear Energy        0.005702
#           Renewables            0.002432
# 2005      Fossil Fuels          0.042666
#           Nuclear Energy        0.005250
#           Renewables            0.003151
# 2006      Fossil Fuels          0.042818
#           Nuclear Energy        0.005894
#           Renewables            0.003891
# 2007      Fossil Fuels          0.047879
#           Nuclear Energy        0.005228
#           Renewables            0.004477
# 2008      Fossil Fuels          0.049435
#           Nuclear Energy        0.006110
#           Renewables            0.005865
# 2009      Fossil Fuels          0.044676
#           Nuclear Energy        0.005413
#           Renewables            0.009902
# 2010      Fossil Fuels          0.049453
#           Nuclear Energy        0.005149
#           Renewables            0.011924
# 2011      Fossil Fuels          0.045533
#           Nuclear Energy        0.006033
#           Renewables            0.013644
# 2012      Fossil Fuels          0.043240
#           Nuclear Energy        0.005029
#           Renewables            0.017293
# 2013      Fossil Fuels          0.040341
#           Nuclear Energy        0.006155
#           Renewables            0.019059
# 2014      Fossil Fuels          0.040777
#           Nuclear Energy        0.004803
#           Renewables            0.020189
# 2015      Fossil Fuels          0.037387
#           Nuclear Energy        0.006065
#           Renewables            0.022085
# 2016      Fossil Fuels          0.032896
#           Nuclear Energy        0.005440
#           Renewables            0.024572
# 2017      Fossil Fuels          0.033928
#           Nuclear Energy        0.006032
#           Renewables            0.025372

# %%
iowa['yearly_total'] = iowa.groupby('year').net_generation.transform('sum')
iowa.head()
# Out:
#                     source  net_generation just_year  yearly_total
# year
# 2001-01-01    Fossil Fuels           35361      2001         40651
# 2001-01-01  Nuclear Energy            3853      2001         40651
# 2001-01-01      Renewables            1437      2001         40651
# 2002-01-01    Fossil Fuels           35991      2002         42528
# 2002-01-01  Nuclear Energy            4574      2002         42528

# %%
iowa.resample('Y').sum().net_generation.plot()
plt.show()

# %% [markdown]
# Lineplot of generation over time, color by source

# %%
iowa.groupby('source').resample('Y').sum().net_generation.plot()
plt.show()

# %% [markdown]
# Display the data as table where years are columns, and energy source is rows (Hint: df.pivot_table)

# %%
iowa.pivot_table('net_generation', 'year', 'source')
# Out:
# source      Fossil Fuels  Nuclear Energy  Renewables
# year
# 2001-01-01         35361            3853        1437
# 2002-01-01         35991            4574        1963
# 2003-01-01         36234            3988        1885
# 2004-01-01         36205            4929        2102
# 2005-01-01         36883            4538        2724
# 2006-01-01         37014            5095        3364
# 2007-01-01         41389            4519        3870
# 2008-01-01         42734            5282        5070
# 2009-01-01         38620            4679        8560
# 2010-01-01         42750            4451       10308
# 2011-01-01         39361            5215       11795
# 2012-01-01         37379            4347       14949
# 2013-01-01         34873            5321       16476
# 2014-01-01         35250            4152       17452
# 2015-01-01         32319            5243       19091
# 2016-01-01         28437            4703       21241
# 2017-01-01         29329            5214       21933

# %% [markdown]
# Make a line plot that shows the amount of energy generated over time. Each source should be a separate line?
# Is the total generation increasing over time?

# %%
iowa.pivot_table('net_generation', 'year', 'source').plot.area(figsize=(12, 8))
