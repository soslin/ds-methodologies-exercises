# %%
import pandas as pd

# %%
from requests import get
url = 'http://www.npr.org'
headers = {'User-Agent' : 'Codeup Data Science Student'}
response = get(url,headers = headers)
print(response.text)
# Out:
# <!doctype html><html class="no-js" lang="en"><head><script>
#    try {var _sf_startpt=(new Date()).getTime();} catch(e){}
# </script>
# <meta itemscope itemtype="https://schema.org/SpeakableSpecification" itemref="speakable" /><title>NPR : National Public Radio : News &amp; Analysis, World, US, Music &amp; Arts : NPR</title><meta id="speakable" itemprop="cssSelector" content="[data-is-speakable]" /><meta id="google-site-verification" name="google-site-verification" content="1VqzbDm4ukeFVHOoq5LjIKA2fVKZD-EYv8cXZhKXSfU" /><meta charset="utf-8" /><meta name="robots" content="noarchive,index,follow" /><meta name="Rating" content="General" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="npr-pjax" /><meta name="date" content="2019-12-04" /><link rel="canonical" href="https://www.npr.org/" /><meta name="description" content="NPR delivers breaking national and world news. Also top stories from business, politics, health, science, technology, music, arts and culture. Subscribe to podcasts and RSS feeds." /><link rel="alternate" type="application/rss+xml" title="Home Page Top Stories" href="/rss/rss.php?id=1002" /><link rel="alternate" type="application/rss+xml" title="NPR News" href="/rss/rss.php?id=1001" /><link rel="alternate" type="application/rss+xml" title="NPR Music" href="/rss/rss.php?id=1039" /><link rel="alternate" type="application/rss+xml" title="NPR Books" href="/rss/rss.php?id=1032" /><link rel="alternate" type="application/rss+xml" title="Morning Edition" href="/rss/rss.php?id=3" /><link rel="alternate" type="application/rss+xml" title="All Things Considered" href="/rss/rss.php?id=2" /><link rel="alternate" type="application/rss+xml" title="Wait Wait... Don't Tell Me!" href="/rss/rss.php?id=35" /><link rel="alternate" type="application/json" title="Home Page Top Stories" href="https://www.npr.org/feeds/1002/feed.json" /><link rel="alternate" type="application/json" title="NPR News" href="https://www.npr.org/feeds/1001/feed.json" /><link rel="alternate" type="application/json" title="NPR Music" href="https://www.npr.org/feeds/1039/feed.json" /><link rel="alternate" type="application/json" title="NPR Books" href="https://www.npr.org/feeds/1032/feed.json" /><link rel="alternate" type="application/json" title="Morning Edition" href="https://www.npr.org/feeds/3/feed.json" /><link rel="alternate" type="application/json" title="All Things Considered" href="https://www.npr.org/feeds/2/feed.json" /><link rel="alternate" type="application/json" title="Wait Wait... Don't Tell Me!" href="https://www.npr.org/feeds/35/feed.json" /><link rel="apple-touch-icon" sizes="180x180" href="https://media.npr.org/templates/favicon/favicon-180x180.png" /><link rel="icon" sizes="96x96" href="https://media.npr.org/templates/favicon/favicon-96x96.png" /><link rel="icon" sizes="32x32" href="https://media.npr.org/templates/favicon/favicon-32x32.png" /><link rel="icon" sizes="16x16" href="https://media.npr.org/templates/favicon/favicon-16x16.png" /><meta property="og:title" content="Home Page Top Stories" /><meta property="og:url" content="https://www.npr.org/" /><meta property="og:type" content="article" /><meta property="og:description" content="NPR delivers breaking national and world news. Also top stories from business, politics, health, science, technology, music, arts and culture. Subscribe to podcasts and RSS feeds." /><meta property="og:image" content="https://media.npr.org/include/images/facebook-default-wide.jpg?s=1400" /><meta property="og:site_name" content="NPR.org" /><meta property="fb:app_id" content="138837436154588" /><meta property="fb:pages" content="10643211755" /><meta property="article:content_tier" content="free" /><meta property="article:opinion" content="false" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:title" content="Home Page Top Stories" /><meta name="twitter:site" content="@NPR" /><meta name="twitter:domain" content="npr.org" /><meta name="twitter:image:src" content="https://media.npr.org/include/images/facebook-default-wide.jpg?s=1400" /><script id="npr-vars">
#    window.NPR = window.NPR || {};
# NPR.ServerConstants = {"cbHost":"npr.org","webHost":"https:\/\/www.npr.org","embedHost":"https:\/\/www.npr.org","webHostSecure":"https:\/\/secure.npr.org","apiHost":"https:\/\/api.npr.org","serverMediaCache":"https:\/\/media.npr.org","googleAnalyticsAccount":"UA-5828686-4","nielsenSFCode":"dcr","nielsenAPN":"NPR-dcr","shouldShowHPLocalContent":true,"readingServiceHostname":"https:\/\/reading.api.npr.org"};
# NPR.serverVars = {"storyId":"1002","refresh":1800,"facebookAppId":"138837436154588","webpackPublicPath":"https:\/\/s.npr.org\/templates\/javascript\/dist\/bundles\/","persistenceVersion":"a72d6cd18d30225929589221ccdf4a45","isBuildOut":true,"pubDate":"2016071413","pageTypeId":"2","title":"Home Page Top Stories","publisherOrgId":"1","experiments":[],"experimentTrackingHost":"https:\/\/ab.npr.org","homePageMetrics":"c1pl,c2ps,c3ps,c4ps,c5ch"};
# </script>
# <script type="text/javascript" src="https://cdn.optimizely.com/js/11107397707.js">
#    </script>
# <script type="text/javascript" src="https://s.npr.org/templates/javascript/lib/modernizr/modernizr.custom.js">
#    </script>
# <script>
#    !function(c){function a(d){if(e[d])return e[d].exports;var f=e[d]={exports:{},id:d,loaded:!1};return c[d].call(f.exports,f,f.exports,a),f.loaded=!0,f.exports}var d=window.webpackJsonp;window.webpackJsonp=function(b,t){for(var n,r,o=0,i=[];o<b.length;o++)r=b[o],f[r]&&i.push.apply(i,f[r]),f[r]=0;for(n in t){var s=t[n];switch(typeof s){case"object":c[n]=function(a){var d=a.slice(1),e=a[0];return function(a,f,b){c[e].apply(this,[a,f,b].concat(d))}}(s);break;case"function":c[n]=s;break;default:c[n]=c[s]}}for(d&&d(b,t);i.length;)i.shift().call(null,a);if(t[0])return e[0]=0,a(0)};var e={},f={25:0};a.e=function(c,d){if(0===f[c])return d.call(null,a);if(void 0!==f[c])f[c].push(d);else{f[c]=[d];var e=document.getElementsByTagName("head")[0],b=document.createElement("script");b.type="text/javascript",b.charset="utf-8",b.async=!0,b.src=a.p+""+c+"."+{0:"4072dca23feb83b12995",1:"46a217a7df47fc2ac049",2:"aadc2fb0532ad2c82603",3:"67cf7a7f7a27215c91b1",4:"2ae334a8d3119c84d059",5:"bcfecf291e65d57a96b2",6:"6ab8d5ecc64394191351",7:"d31a9f38ffaf765f2d1c",8:"d301a0cf12f9b8638757",9:"106c41651d46dfb46909",10:"4601f162098a3bacd566",11:"8b854f4bad13b3115003",12:"8225fa7a15742460e72a",13:"eb64e7ca8492777004ab",14:"a1319df042a61d808054",15:"0e334f93d5e25c5985e0",16:"f18f5bcac3e2ba414c0b",17:"645bd8be7fd62c52c497",18:"7c68717c2ba6f38842df",19:"e1b254e3bc96bb1aa64e",20:"67e568226515de4e9c7d",21:"babff51771902453eb7c",22:"dc248295b281710e3eb9",23:"3c9d01488dac43774425",24:"7df1caf2e39b3e5059cf",26:"1426c8dc0dcd02dff47c",27:"794a3c813fd808e06d53",28:"900d9ff9f28fc6ff35fc",29:"8814a9cec1caab242de6",30:"e4e882da5f541138d3e0",31:"cb5989d444c51f1cc9cc",32:"34dd08b44d905a6af82c",33:"35a7bbb25dc24ce83c0d",34:"e11fca908ed9f2590606",35:"1a113dd16f30d574a712",36:"5dadd4d13a6a801fb99c",37:"897f5382f907c6d5967d",38:"7373708aa4e0b213c851",39:"71afd5861d865089f4ec",40:"f999482f7d7e4cc5e1b3",41:"007564165c1f1074f138",42:"67a4b42b57945ecd6d1f",43:"d902751e00a788ef3fcf",44:"65286d78ffc331b13f33",45:"526e1af6cba7cbdef434",46:"de63721affa6462fbdd0",47:"10c90dd6361478141a56",48:"864a251267da20fbd532",49:"16ca131aaa3214d9aae0",50:"38578bb3a12496bf3c5c",51:"f357380309d6c99d36f0",52:"aae210a38f06f33c4a32",53:"06fdb6672d7b3890a79a",54:"8cec882709993bc47dbe",55:"e5ad62ba3b03b9580f49",56:"c6ab1ae734f5acf3843a",57:"94d257e702eb24205852",58:"83086b5c9700cb272c92",59:"b90b8b522b3ef06f58b6",60:"f30d5ce8bcc8e8cb856d",61:"617a31d69fcaa568b52f",62:"420b8f5c605d35ca7658",63:"4a0f2c73ceb390bf6bdd",64:"1d4e4fadb56d60163be2",65:"714d9572440831c5126d",66:"10c37b3bd2c816c0651a",67:"7346a051cda6ced53c9e",68:"b1e1628e1287ad29d418",69:"55a7fb6a7b9364847ece",70:"87d8144b6630b280d92b",71:"8a1764b1dc4dddf80de5",72:"104dac8061a1df41d7a8",73:"10ca74fe5af701f3be8a",74:"cd02cf65ccb84504cc9b",75:"b3b8d08f1687417df916",76:"a2c10bb584b53d6fb365",77:"324553d4fac65c742e5b",78:"801455e7d71d17a04973",79:"67d073bd0d1880cb3b4f",80:"2b85a5e2c6b69c035aa4",81:"ceaf00ce764123ddfb08",82:"918a6a88354be6048a9e",83:"06cd03e028d30da3f422",84:"ad22ee40122baad338c2",85:"ec09e20a4a8bc9774522"}[c]+".chunk.js",e.appendChild(b)}},a.m=c,a.c=e,a.p="/templates/javascript/dist/bundles/"}(function(c){for(var a in c)if(Object.prototype.hasOwnProperty.call(c,a))switch(typeof c[a]){case"function":break;case"object":c[a]=function(a){var d=a.slice(1),e=c[a[0]];return function(c,a,f){e.apply(this,[c,a,f].concat(d))}}(c[a]);break;default:c[a]=c[c[a]]}return c}([]));
# </script>
# <script type="text/javascript" src="https://s.npr.org/templates/javascript/dist/bundles/globalNavigationDropdowns-794a3c813fd808e06d53.js">
#    </script>
# <link rel="stylesheet" data-persist="true" media="screen, print" href="https://s.npr.org/templates/javascript/dist/bundles/persistent-css-e82a4154aefeded5d519.css" /><link rel="stylesheet" media="screen, print" href="https://s.npr.org/templates/javascript/dist/bundles/newsHp2-css-e82a4154aefeded5d519.css" /><script type="text/javascript">
#    document.domain="npr.org";
# </script>
# </head><body id="news" class="news tmplHomePage agg id1002  " data-pjax-modules="util/env images/lazy-load chartbeat comscore metrics nielsen nielsenDCR copyright auto-refresh navigation/global-navigation fitvids dfp globalfooter persistent-audio player/more-options player/audio-module-clickable what-input metrics/doubleclickFloodlight metrics/facebookTracking story/replace-centerstage global-modal global-stickybar home/base jw home/header home/local-content slideshow images/enlargement images/captions images/hover-credits callout/end-of-story-callout podcast-cards social/recaptcha"><div class="skip-links">
#       <span>Accessibility links</span>   <ul>
#             <li><a href="#mainContent" class="skiplink">Skip to main content</a></li>
#       <li><a href="https://help.npr.org/customer/en/portal/articles/2535181-what-are-the-keyboard-shortcuts-for-using-the-npr-org-audio-player-" class="skiplink">Keyboard shortcuts for audio player</a></li>
#    </ul>
# </div>
# <header class="npr-header" id="globalheader" aria-label="NPR header">
# <nav class="navigation" aria-label="main navigation">
#     <div class="navigation__top-level-wrap" data-metrics-all data-metrics-category="global navigation">
#         <ul class="navigation__top-level">
#             <li class="navigation__home">
#                 <a href="/" data-metrics-action="click npr logo">
#                     <img src="https://media.npr.org/chrome_svg/npr-logo.svg" alt="NPR logo"/>
#                 </a>
#             </li>
#
#             <li id="navigation__station-mount"></li>
#
#             <li id="user-account-dropdown-mount" class="navigation__account"></li>
#
#             <li class="navigation__shop">
#                 <a href="https://shop.npr.org" data-metrics-action="click npr shop">NPR Shop</a>
#             </li>
#
#             <li id="navigation__station-donate-mount"></li>
#
#             <li class="navigation__toggle-wrap">
#                 <button id="navigation__toggle--open" class="navigation__toggle navigation__toggle--open" aria-haspopup="true" aria-expanded="false" data-metrics-action="open navigation menu">
#                     Open Navigation Menu
#                 </button>
#             </li>
#         </ul>
#     </div>
#     <section id="main-menu" class="menu menu--main" data-metrics-all data-metrics-category="global navigation">
#         <div class="menu__inner">
#             <header class="menu__header">
#                 <button id="navigation__toggle--close" class="navigation__toggle navigation__toggle--close" aria-haspopup="true" aria-expanded="true" data-metrics-action="close navigation menu">
#                     Close <span>Navigation Menu</span>
#                 </button>
#             </header>
#             <ul class="menu__list">
#                 <li class="menu__item menu__item--home">
#                     <div class="menu__item-inner"><a href="/" data-metrics-action="click npr logo">Home</a></div>
#                 </li>
#                 <li class="menu__item menu__item--news menu__item--has-submenu" data-metrics-hover="toggle news drawer">
#                     <div class="menu__item-inner">
#                         <a href="/sections/news/" data-metrics-action="click news">News</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle news drawer">Expand/collapse submenu for News</button>
#                     </div>
#
#                     <ul class="submenu submenu--news">
#                         <li class="submenu__item"><a href="/sections/national/" data-metrics-action="click national">National</a></li>
#                         <li class="submenu__item"><a href="/sections/world/" data-metrics-action="click world">World</a></li>
#                         <li class="submenu__item"><a href="/sections/politics/" data-metrics-action="click politics">Politics</a></li>
#                         <li class="submenu__item"><a href="/sections/business/" data-metrics-action="click business">Business</a></li>
#                         <li class="submenu__item"><a href="/sections/health/" data-metrics-action="click health">Health</a></li>
#                         <li class="submenu__item"><a href="/sections/science/" data-metrics-action="click science">Science</a></li>
#                         <li class="submenu__item"><a href="/sections/technology/" data-metrics-action="click technology">Technology</a></li>
#                         <li class="submenu__item"><a href="/sections/codeswitch/" data-metrics-action="click race & culture">Race &amp; Culture</a></li>
#                     </ul>
#                 </li>
#                 <li class="menu__item menu__item--arts-life menu__item--has-submenu" data-metrics-hover="toggle arts drawer">
#                     <div class="menu__item-inner">
#                         <a href="/sections/arts/" data-metrics-action="click arts & life">Arts &amp; Life</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle arts drawer">Expand/collapse submenu for Arts &amp; Life</button>
#                     </div>
#
#                     <ul class="submenu submenu--arts-life">
#                         <li class="submenu__item"><a href="/books/" data-metrics-action="click books">Books</a></li>
#                         <li class="submenu__item"><a href="/sections/movies/" data-metrics-action="click movies">Movies</a></li>
#                         <li class="submenu__item"><a href="/sections/television/" data-metrics-action="click television">Television</a></li>
#                         <li class="submenu__item"><a href="/sections/pop-culture/" data-metrics-action="click pop culture">Pop Culture</a></li>
#                         <li class="submenu__item"><a href="/sections/food/" data-metrics-action="click food">Food</a></li>
#                         <li class="submenu__item"><a href="/sections/art-design/" data-metrics-action="click art & design">Art &amp; Design</a> </li>
#                         <li class="submenu__item"><a href="/sections/performing-arts/" data-metrics-action="click performing arts">Performing Arts</a></li>
#                     </ul>
#                 </li>
#                 <li class="menu__item menu__item--music menu__item--has-submenu" data-metrics-hover="toggle music drawer">
#                     <div class="menu__item-inner">
#                         <a href="/music/" data-metrics-action="click music">Music</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle music drawer">Expand/collapse submenu for Music</button>
#                     </div>
#
#                     <ul class="submenu submenu--music"><li class="submenu__item">
#     <a href="https://www.npr.org/series/tiny-desk-concerts/" data-metrics-action="click tiny desk">
#         Tiny Desk
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/allsongs/" data-metrics-action="click all songs considered">
#         All Songs Considered
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/music-news/" data-metrics-action="click music news">
#         Music News
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/sections/new-music/" data-metrics-action="click new music">
#         New Music
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/series/770565791/npr-music-live-sessions" data-metrics-action="click live sessions">
#         Live Sessions
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/series/689345495/best-music-of-2019" data-metrics-action="click best music of 2019">
#         Best Music Of 2019
#     </a>
# </li></ul>
#
#                 </li>
#                 <li class="menu__item menu__item--shows-podcasts menu__item--has-submenu" data-metrics-hover="toggle programs &amp; podcasts drawer">
#                     <div class="menu__item-inner">
#                         <a href="/programs/" data-metrics-action="click shows & podcasts">Shows &amp; Podcasts</a>
#                         <button class="menu__toggle-submenu" data-metrics-action="toggle programs &amp; podcasts drawer">Expand/collapse submenu for Shows &amp; Podcasts</button>
#                     </div>
#
#                     <div class="submenu submenu--shows-podcasts">
#                         <span class="submenu__category submenu__category--daily">Daily</span>
#                         <ul class="submenu__list submenu__list--daily">
#                             <li class="submenu__item submenu__item--timed submenu__item--weekday hidden">
#                                 <a href="/programs/morning-edition/" data-metrics-action="click morning edition">
#                                     <img src="https://media.npr.org/chrome/programs/logos/morning-edition.jpg" alt="" />
#                                     Morning Edition
#                                 </a>
#                             </li>
#                             <li class="submenu__item submenu__item--timed submenu__item--saturday hidden" >
#                                 <a href="/programs/weekend-edition-saturday/" data-metrics-action="click weekend edition saturday">
#                                     <img src="https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesat_sq-cbde87a2fa31b01047441e6f34d2769b0287bcd4-s100-c85.png" alt="" />
#                                     Weekend Edition Saturday
#                                 </a>
#                             </li>
#                             <li class="submenu__item submenu__item--timed submenu__item--sunday hidden">
#                                 <a href="/programs/weekend-edition-sunday/" data-metrics-action="click weekend edition sunday">
#                                     <img src="https://media.npr.org/assets/img/2019/02/26/we_otherentitiestemplatesun_sq-4a03b35e7e5adfa446aec374523a578d54dc9bf5-s100-c85.png" alt="" />
#                                     Weekend Edition Sunday
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/programs/all-things-considered/" data-metrics-action="click all things considered">
#                                     <img src="https://media.npr.org/chrome/programs/logos/all-things-considered.png" alt="" />
#                                     All Things Considered
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/programs/fresh-air/" data-metrics-action="click fresh air">
#                                     <img src="https://media.npr.org/chrome/programs/logos/fresh-air.png" alt="" />
#                                     Fresh Air
#                                 </a>
#                             </li>
#                             <li class="submenu__item">
#                                 <a href="/podcasts/510318/up-first" data-metrics-action="click up first">
#                                     <img src="https://media.npr.org/chrome/programs/logos/up-first.jpg?version=2" alt="" />
#                                     Up First
#                                 </a>
#                             </li>
#                         </ul>
#                         <span class="submenu__category submenu__category--featured">Featured</span>
#
#                         <ul class="submenu__list submenu__list--featured"><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510313/how-i-built-this" data-metrics-action="click how i built this with guy raz">
#         <img src="https://media.npr.org/assets/img/2018/08/03/npr_hibt_podcasttile_sq-98320b282169a8cea04a406530e6e7b957665b3f.jpg?s=100" alt="" />
#         How I Built This with Guy Raz
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/344098539/wait-wait-don-t-tell-me" data-metrics-action="click wait wait... don't tell me!">
#         <img src="https://media.npr.org/assets/img/2019/11/20/npr_91201389-1-_sq-ca0128ef6da8bbc571cf2bc15e5aecb4d1b33fb4.jpg?s=100" alt="" />
#         Wait Wait... Don't Tell Me!
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510289/planet-money" data-metrics-action="click planet money">
#         <img src="https://media.npr.org/assets/img/2018/08/02/npr_planetmoney_podcasttile_sq-7b7fab0b52fd72826936c3dbe51cff94889797a0.jpg?s=100" alt="" />
#         Planet Money
#     </a>
# </li><li class="submenu__item">
#     <a href="https://www.npr.org/podcasts/510308/hidden-brain" data-metrics-action="click hidden brain">
#         <img src="https://media.npr.org/assets/img/2018/08/03/npr_hiddenbrain_podcasttile_sq-270ab642de6948802f485c6ad1f087239ef6e324.jpg?s=100" alt="" />
#         Hidden Brain
#     </a>
# </li></ul>
#
#                         <ul class="submenu__list submenu__list--directories">
#                             <li class="submenu__item"><a href="/programs/" data-metrics-action="click all programs">More Shows &amp; Podcasts</a></li>
#                         </ul>
#                     </div>
#                 </li>
#                 <li class="menu__item menu__item--search">
#                     <div class="menu__item-inner">
#                         <a href="/search" id="navigation_dropdown-search" data-metrics-action="click search">Search</a>
#                     </div>
#                 </li>
#                 <li id="user-account-dropdown-mount-two" class="menu__item menu__item--account"></li>
#                 <li class="menu__item menu__item--shop">
#                     <div class="menu__item-inner">
#                         <a href="https://shop.npr.org" data-metrics-action="click npr shop">NPR Shop</a>
#                     </div>
#                 </li>
#             </ul>
#         </div>
#     </section>
#     <section class="menu menu--music" data-metrics-all data-metrics-category="music ecosystem navigation">
#         <div class="menu__list-wrap">
#             <ul class="menu__list menu__list--ecosystem menu__list--music">
#                 <li class="menu__item menu__item--music-home">
#                     <a href="/music/" data-metrics-action="click npr music logo">
#                         <img src="https://media.npr.org/chrome_svg/music-logo-dark.svg" class="music-logo"  alt="NPR Music" />
#                         <img src="https://media.npr.org/chrome_svg/music-logo-light.svg" class="music-logo-alt" alt="NPR Music" />
#                     </a>
#                 </li>
#
#                 <li class="menu__item">
#     <a href="https://www.npr.org/series/tiny-desk-concerts/" data-metrics-action="click tiny desk">
#         Tiny Desk
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/allsongs/" data-metrics-action="click all songs considered">
#         All Songs Considered
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/music-news/" data-metrics-action="click music news">
#         Music News
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/sections/new-music/" data-metrics-action="click new music">
#         New Music
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/series/770565791/npr-music-live-sessions" data-metrics-action="click live sessions">
#         Live Sessions
#     </a>
# </li><li class="menu__item">
#     <a href="https://www.npr.org/series/689345495/best-music-of-2019" data-metrics-action="click best music of 2019">
#         Best Music Of 2019
#     </a>
# </li>
#             </ul>
#         </div>
#     </section>
#     <section class="menu menu--about" data-metrics-all data-metrics-category="about ecosystem navigation">
#         <div class="menu__list-wrap">
#             <ul class="menu__list menu__list--ecosystem menu__list--about">
#                 <li class="menu__item menu__item--about-home"><a href="/about/" data-metrics-action="click about npr">About NPR</a></li>
#                 <li class="menu__item menu__item--about-overview"><a href="/overview/" data-metrics-action="click overview">Overview</a></li>
#                 <li class="menu__item menu__item--about-support"><a href="/support/" data-metrics-action="click support">Support</a></li>
#                 <li class="menu__item menu__item--about-careers"><a href="/careers/" data-metrics-action="click careers">Careers</a></li>
#                 <li class="menu__item menu__item--about-connect"><a href="/connect/" data-metrics-action="click connect">Connect</a></li>
#                 <li class="menu__item menu__item--about-press"><a href="/press/" data-metrics-action="click press">Press</a></li>
#                 <li class="menu__item menu__item--about-ethics"><a href="/ethics/" data-metrics-action="click ethics">Ethics</a></li>
#             </ul>
#         </div>
#     </section>
# </nav></header><main aria-label="main content"><div class="speakable">
#       <b data-is-speakable>NPR : National Public Radio : News & Analysis, World, US, Music & Arts</b>   <b data-is-speakable>NPR delivers breaking national and world news. Also top stories from business, politics, health, science, technology, music, arts and culture. Subscribe to podcasts and RSS feeds.</b>
# </div>
# <div id="wrapper">
#       <section id="main-section"><a id="mainContent"></a><div id="experimentWrap">
#       <style type="text/css">article.experimentVariant { display: none; }
# </style>   <script type='text/javascript'>
#     // helper functions
#     var generateIdForExperimentVariant = function(experimentId, variantId) {
#       return 'article.experimentVariant#story' + experimentId.toString() +  variantId.toString();
#     };
#
#     NPR.serverVars.experimentMetrics = [];
#     var experimentStyles = '';
#
#     var experimentList = NPR.serverVars.experiments || [];
#     experimentList.forEach(function(experiment) {
#         var experimentId = experiment.id;
#         var experimentStoryId = experiment.storyId;
#         var variants = experiment.variants;
#
#         if (!variants || !variants.length) {
#             return;
#         }
#
#         var randomValue =  Math.random();
#
#         // select a variant weighted on the frequencies in the variant metadata
#         // the frequencies are between 0 and 1, and the sum of the frequencies add up to 1
#         var weightedSum = 0;
#         var variantId = variants[0].id;
#         var pickedOne = false;
#         for (var index = 0; index < variants.length; index++) {
#             var variant = variants[index];
#             weightedSum += parseFloat(variant.freq);
#
#             if (!pickedOne && randomValue <= weightedSum) {
#                 variantId = variant.id;
#                 pickedOne = true;
#                 experimentStyles += generateIdForExperimentVariant(experimentStoryId, variant.id) + ' { display:block;} \n';
#             }
#             else {
#                 experimentStyles += generateIdForExperimentVariant(experimentStoryId, variant.id) + ' { display:none;} \n';
#             }
#         }
#         // store info for use by Google Analytics later
#         NPR.serverVars.experimentMetrics.push([experimentId,variantId,experimentStoryId]);
#
#         // https://www.admonsters.com/blog/pixel-delivery-best-practices
#         // http://stackoverflow.com/a/22419389
#         (new Image()).src = NPR.serverVars.experimentTrackingHost + '/abtesting/experiments/' + experimentId + '/variants/' +  variantId + '/impression.gif';
#     });
#
#     // attaching the live click handler
#     document.addEventListener('click', function (event) {
#         if (NPR.serverVars.experimentMetrics && NPR.serverVars.experimentMetrics.constructor === Array) {
#             NPR.serverVars.experimentMetrics.forEach(function (experimentVariant) {
#                 var experimentId = experimentVariant[0];
#                 var variantId = experimentVariant[1];
#                 var experimentStoryId = experimentVariant[2];
#
#                 var idToSearchFor = 'story' + experimentStoryId + variantId;
#                 var el = event.target
#                         , found;
#
#                 while (el && !(found = el.id === idToSearchFor)) {
#                     el = el.parentElement;
#                 }
#
#                 if (found) {
#                     (new Image()).src = NPR.serverVars.experimentTrackingHost + '/abtesting/experiments/' + experimentId + '/variants/' + variantId + '/click.gif';
#                 }
#             });
#         }
#     });
#
#     var styleDiv = document.createElement('div');
#     styleDiv.innerHTML = '<style>' + experimentStyles + '</style>';
#     document.getElementById('experimentWrap').appendChild(styleDiv.childNodes[0]);
# </script>
# </div>
#
# <!-- END ID="EXPERIMENTWRAP" -->
# <div id="contentWrap">
#       <div class="stories-wrap stories-wrap-featured" data-metrics-category="Curated List">
#             <section class="attachment-group">
#   <article class="hp-item volume-low post-type-standard has-attachment has-image "  id="story784186196"  >
#
#
#
#     <div class="story-wrap">
#
#         <figure class="thumb-image">
#             <div class="bucketwrap homeThumb">
#                 <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2019/12/04/784186196/judiciary-hearing-to-open-final-act-of-democrats-trump-impeachment-saga" data-metrics='{"action":"Click Story 1"}' >
#         <img src="https://media.npr.org/assets/img/2019/12/04/gettyimages-1186479753_wide-4f624df70471a80a3bb294362ab3651ccc451127-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2019/12/04/gettyimages-1186479753_wide-4f624df70471a80a3bb294362ab3651ccc451127-s400.jpg" class="img lazyOnLoad"  alt="Judiciary Hearing Opens Final Act Of Democrats' Trump Impeachment Saga" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 House Judiciary Committee Chairman Jerry Nadler, D-N.Y., (left) looks on as ranking member Rep. Doug Collins, R-Ga., speaks before an impeachment hearing where constitutional scholars are testifying about the impeachment inquiry into President Trump on Wednesday.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Drew Angerer/Getty Images
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Drew Angerer/Getty Images
#
#     </span>
# </div>
#
#             </div>
#         </figure>
#
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                     <h2 class="slug">
#                         <a href="https://www.npr.org/series/771270514/trump-impeachment-inquiry" data-metrics='{"action":"Click Slug"}'>
#                         Trump Impeachment Inquiry
#                         </a>
#                     </h2>
#                 </div>
#             <a href="https://www.npr.org/2019/12/04/784186196/judiciary-hearing-to-open-final-act-of-democrats-trump-impeachment-saga" data-metrics='{"action" : "Click Story 1"}'>
#                 <h3 class="title">Judiciary Hearing Opens Final Act Of Democrats' Trump Impeachment Saga</h3>
#             </a>
#
#
#             <a href="https://www.npr.org/2019/12/04/784186196/judiciary-hearing-to-open-final-act-of-democrats-trump-impeachment-saga" data-metrics='{"action" : "Click Story 1"}'>
#                 <p class="teaser">A panel of four constitutional law scholars are trying to put the allegations against Trump in a historical and legal context. Three of the professors support impeachment, one is opposed.</p>
#             </a>
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# <article class="hp-item attachment volume-low">
#     <a class="story-wrap" href="https://www.npr.org/2019/12/03/784263045/schiff-impeachment-report-expected-tuesday-after-republicans-defense-of-trump" data-metrics='{"action" : "Click Attached Story 1"}'>
#         <div class="story-text">
#             <h3 class="title">House Democrats' New Report: Top Trump Officials Knew Of Ukraine Scheme</h3>
#         </div>
#     </a>
# </article>
# <article class="hp-item attachment volume-low">
#     <a class="story-wrap" href="https://www.npr.org/2019/12/03/784368506/rep-adam-schiff-the-uncontested-facts-show-this-president-solicited-a-bribe" data-metrics='{"action" : "Click Attached Story 1"}'>
#         <div class="story-text">
#             <h3 class="title">Rep. Adam Schiff: 'The Uncontested Facts Show This President Solicited A Bribe'</h3>
#         </div>
#     </a>
# </article>
#
# </section>
#       <section class="featured-group"><article class="hp-item hp-item-basic post-type-standard has-image "  id="story784819728"  >
#     <div class="story-wrap">
#             <figure class="thumb-image">
#                 <div class="bucketwrap homeThumb">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2019/12/04/784819728/giuliani-nunes-and-1-a-look-at-what-the-impeachment-report-phone-records-mean" data-metrics='{"action":"Click Story 2"}' >
#         <img src="https://media.npr.org/assets/img/2019/12/04/ap_19338006250665_wide-d6e507897cb1ce07a91b0877aadf1983316c5790-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2019/12/04/ap_19338006250665_wide-d6e507897cb1ce07a91b0877aadf1983316c5790-s400.jpg" class="img lazyOnLoad"  alt="Giuliani, Nunes and '-1,': A Look At What The Impeachment Report Phone Records Mean" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 Rep. Devin Nunes, R-Calif., stands in an elevator after departing a secure area of the Capitol in Washington, Tuesday, Dec. 3, 2019. His appearance in call logs in the Democrats' impeachment report is raising new questions about his role in the Ukrainian pressure campaign at the heart of the impeachment inquiry.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Patrick Semansky/AP
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Patrick Semansky/AP
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                         <h2 class="slug">
#                             <a href="https://www.npr.org/series/771270514/trump-impeachment-inquiry" data-metrics='{"action":"Click Slug"}'>
#                             Trump Impeachment Inquiry
#                             </a>
#                         </h2>
#                 </div>
#             <a href="https://www.npr.org/2019/12/04/784819728/giuliani-nunes-and-1-a-look-at-what-the-impeachment-report-phone-records-mean" data-metrics='{"action" : "Click Story 2"}'>
#             <h3 class="title">Giuliani, Nunes and '-1,': A Look At What The Impeachment Report Phone Records Mean</h3>
#             </a>
#
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# <article class="hp-item hp-item-basic post-type-audio has-image "  id="story776058798"  >
#     <div class="story-wrap">
#             <figure class="thumb-image">
#                 <div class="bucketwrap homeThumb">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2019/12/04/776058798/why-student-loan-borrowers-with-disabilities-arent-getting-the-help-they-deserve" data-metrics='{"action":"Click Story 3"}' >
#         <img src="https://media.npr.org/assets/img/2019/12/04/_dsc3248_wide-5c2f5de9f218e36bf6f14512fafd555a9f35e98b-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2019/12/04/_dsc3248_wide-5c2f5de9f218e36bf6f14512fafd555a9f35e98b-s400.jpg" class="img lazyOnLoad"  alt="Student Loan Borrowers With Disabilities Aren't Getting Help They Were Promised" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 Drew Lehman of Lansdale, Pa., became unable to work after a traumatic car accident.
#
#                 <b class="credit" aria-label="Image credit">
#
#                                                     /Natalie Piserchio for NPR
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#                                         /Natalie Piserchio for NPR
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                         <h2 class="slug">
#                             <a href="https://www.npr.org/sections/education/" data-metrics='{"action":"Click Slug"}'>
#                             Education
#                             </a>
#                         </h2>
#                 </div>
#             <a href="https://www.npr.org/2019/12/04/776058798/why-student-loan-borrowers-with-disabilities-arent-getting-the-help-they-deserve" data-metrics='{"action" : "Click Story 3"}'>
#             <h3 class="title">Borrowers With Disabilities Were Promised Student Loan Relief. Most Don't Get It</h3>
#             </a>
#
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# <article class="hp-item hp-item-basic post-type-audio has-image "  id="story784416386"  >
#     <div class="story-wrap">
#             <figure class="thumb-image">
#                 <div class="bucketwrap homeThumb">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2019/12/04/784416386/on-the-oregon-coast-turning-pollution-into-art-with-a-purpose" data-metrics='{"action":"Click Story 4"}' >
#         <img src="https://media.npr.org/assets/img/2019/12/04/angela-on-beach-4_wide-dae267c1088f766452097f3659021d3bcc79c589-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2019/12/04/angela-on-beach-4_wide-dae267c1088f766452097f3659021d3bcc79c589-s400.jpg" class="img lazyOnLoad"  alt="On The Oregon Coast, Turning Pollution Into Art With A Purpose" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 Angela Haseltine Pozzi founded Washed Ashore in 2010. The nonprofit turns plastics taken from Oregon's beaches into eye-opening sculptures of threatened marine life.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Kirk Siegler/NPR
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Kirk Siegler/NPR
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                         <h2 class="slug">
#                             <a href="https://www.npr.org/sections/environment/" data-metrics='{"action":"Click Slug"}'>
#                             Environment
#                             </a>
#                         </h2>
#                 </div>
#             <a href="https://www.npr.org/2019/12/04/784416386/on-the-oregon-coast-turning-pollution-into-art-with-a-purpose" data-metrics='{"action" : "Click Story 4"}'>
#             <h3 class="title">On The Oregon Coast, Turning Pollution Into Art With A Purpose</h3>
#             </a>
#
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
# </section>
# <!-- END CLASS="FEATURED-GROUP" -->
#    </div>
#
# <!-- END CLASS="STORIES-WRAP STORIES-WRAP-FEATURED" DATA-METRICS-CATEGORY="CURATED LIST" -->
#    <div class="centerstage-outer-wrap">
#             <p class="centerstage-sponsor-language"><span>More NPR content after sponsor message</span></p>      <aside id="ad-centerstage-wrap" aria-label="advertisement">
#
#
#     <div id="ad-centerstage-homepage" class="ad-centerstage" data-ad-config='{"network":"\/6735\/","site":{"default":"n6735.NPR","mobile":"n6735.NPRMOBILE"},"zone":"homepage","targets":{"testserver":"false","isPodcastEpisode":"false","storyId":"1002"},"location":"centerstage","deferred":false,"isBetweenContent":false,"isAggSponsorship":false,"borderClass":""}'></div>
#
# </aside>
#    </div>
#
# <!-- END CLASS="CENTERSTAGE-OUTER-WRAP" -->
#    <section id="local-content-mount"></section>
# <!-- END ID="LOCAL-CONTENT-MOUNT" -->
#    <div class="stories-wrap stories-wrap-two" data-metrics-category="Curated List">
#             <article class="hp-item volume-high post-type-videocarousel no-image "  id="story656281336"  >
#
#     <div class="story-wrap-outer">
#         <div class="video-header">
#       <h2 class="watch-videos">WATCH</h2>
#    <a class="more-videos" href="/video"><b>MORE VIDEOS</b></a>
# </div>
#
# <!-- END CLASS="VIDEO-HEADER" -->
# <div id="jwPlaylist656281336" class="player-playlist-wrapper">
#       <div class="player">
#             <div class="player-shelf" id="player-shelf656281336">
#                </div>
#
# <!-- END CLASS="PLAYER-SHELF" ID="PLAYER-SHELF656281336" -->
#    </div>
#
# <!-- END CLASS="PLAYER" -->
#    <div class="playlist-wrapper">
#             <div class="playlist__gradient playlist__gradient--top">
#                </div>
#       <ul class="playlist" data-metrics-all>
#                   <li class="playlist-item" data-metrics='{"action":"select video from coming up","category":"JW Player Video","label":"Sheryl Crow: Tiny Desk Concert", "type":"customEvent", "customDimensions":{ "dimension47":"/2019/12/03/784151410/sheryl-crow-tiny-desk-concert","dimension48":"Sheryl Crow: Tiny Desk Concert","dimension49":"2107" }}' ><a class="playlist-item-link" tabindex="0" data-mediaid="/2019/12/03/784151410/sheryl-crow-tiny-desk-concert" ><div class="playlist-thumbnail-wrapper">
#       <span class="playlist-formatDuration">00:35:07</span>   <div class="playlist-item-playing">
#          </div>
#
# <!-- END CLASS="PLAYLIST-ITEM-PLAYING" -->
#    <img class="playlist-thumbnail" src="https://media.npr.org/assets/img/2019/12/02/sherylcrow_mshaw_wide-7d9cb4361ab0e68d465c19ae4645e86c651b2adf-s800-c85.jpg" />
# </div>
#
# <!-- END CLASS="PLAYLIST-THUMBNAIL-WRAPPER" -->
# <p>Sheryl Crow: Tiny Desk Concert</p></a></li>
#          <li class="playlist-item" data-metrics='{"action":"select video from coming up","category":"JW Player Video","label":"Megan Thee Stallion: Tiny Desk Concert", "type":"customEvent", "customDimensions":{ "dimension47":"/2019/12/02/782026665/megan-thee-stallion-tiny-desk-concert","dimension48":"Megan Thee Stallion: Tiny Desk Concert","dimension49":"1559" }}' ><a class="playlist-item-link" tabindex="0" data-mediaid="/2019/12/02/782026665/megan-thee-stallion-tiny-desk-concert" ><div class="playlist-thumbnail-wrapper">
#       <span class="playlist-formatDuration">00:25:59</span>   <div class="playlist-item-playing">
#          </div>
#
# <!-- END CLASS="PLAYLIST-ITEM-PLAYING" -->
#    <img class="playlist-thumbnail" src="https://media.npr.org/assets/img/2019/11/25/megan-thee-stallion-phony-ppl_lbeltranvillamizar-3_wide-79bc6026bb8a76ea1f56377c41c7e565059bf2b4-s800-c85.jpg" />
# </div>
#
# <!-- END CLASS="PLAYLIST-THUMBNAIL-WRAPPER" -->
# <p>Megan Thee Stallion: Tiny Desk Concert</p></a></li>
#          <li class="playlist-item" data-metrics='{"action":"select video from coming up","category":"JW Player Video","label":"Black Uhuru: Tiny Desk Concert", "type":"customEvent", "customDimensions":{ "dimension47":"/2019/11/29/781859473/black-uhuru-tiny-desk-concert","dimension48":"Black Uhuru: Tiny Desk Concert","dimension49":"945" }}' ><a class="playlist-item-link" tabindex="0" data-mediaid="/2019/11/29/781859473/black-uhuru-tiny-desk-concert" ><div class="playlist-thumbnail-wrapper">
#       <span class="playlist-formatDuration">00:15:45</span>   <div class="playlist-item-playing">
#          </div>
#
# <!-- END CLASS="PLAYLIST-ITEM-PLAYING" -->
#    <img class="playlist-thumbnail" src="https://media.npr.org/assets/img/2019/11/25/blackuhuru-charbage-1_wide-b613fc9b3c0e64c60b906fd7208f6fabb6cb4791-s800-c85.jpg" />
# </div>
#
# <!-- END CLASS="PLAYLIST-THUMBNAIL-WRAPPER" -->
# <p>Black Uhuru: Tiny Desk Concert</p></a></li>
#          <li class="playlist-item" data-metrics='{"action":"select video from coming up","category":"JW Player Video","label":"Mereba: Tiny Desk Concert", "type":"customEvent", "customDimensions":{ "dimension47":"/2019/11/27/781847438/mereba-tiny-desk-concert","dimension48":"Mereba: Tiny Desk Concert","dimension49":"941" }}' ><a class="playlist-item-link" tabindex="0" data-mediaid="/2019/11/27/781847438/mereba-tiny-desk-concert" ><div class="playlist-thumbnail-wrapper">
#       <span class="playlist-formatDuration">00:15:41</span>   <div class="playlist-item-playing">
#          </div>
#
# <!-- END CLASS="PLAYLIST-ITEM-PLAYING" -->
#    <img class="playlist-thumbnail" src="https://media.npr.org/assets/img/2019/11/22/mereba-mshaw_wide-d259175b3256d532f05d284f2652e7434cf6b21e-s800-c85.jpg" />
# </div>
#
# <!-- END CLASS="PLAYLIST-THUMBNAIL-WRAPPER" -->
# <p>Mereba: Tiny Desk Concert</p></a></li>
#          <li class="playlist-item" data-metrics='{"action":"select video from coming up","category":"JW Player Video","label":"Carly Rae Jepsen: Tiny Desk Concert", "type":"customEvent", "customDimensions":{ "dimension47":"/2019/11/25/781452256/carly-rae-jepsen-tiny-desk-concert","dimension48":"Carly Rae Jepsen: Tiny Desk Concert","dimension49":"607" }}' ><a class="playlist-item-link" tabindex="0" data-mediaid="/2019/11/25/781452256/carly-rae-jepsen-tiny-desk-concert" ><div class="playlist-thumbnail-wrapper">
#       <span class="playlist-formatDuration">00:10:07</span>   <div class="playlist-item-playing">
#          </div>
#
# <!-- END CLASS="PLAYLIST-ITEM-PLAYING" -->
#    <img class="playlist-thumbnail" src="https://media.npr.org/assets/img/2019/11/22/carlyrayjepsen-mshaw_wide-458affc59f7518052a27c8915d58910ce59b54c5-s800-c85.jpg" />
# </div>
#
# <!-- END CLASS="PLAYLIST-THUMBNAIL-WRAPPER" -->
# <p>Carly Rae Jepsen: Tiny Desk Concert</p></a></li>
# ...
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Sean Gallup/Getty Images
#
#     </span>
# </div>
#
#             </div>
#         </figure>
#
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                     <h2 class="slug">
#                         <a href="https://www.npr.org/sections/europe/" data-metrics='{"action":"Click Slug"}'>
#                         Europe
#                         </a>
#                     </h2>
#                 </div>
#             <a href="https://www.npr.org/2019/12/04/784693025/germany-expels-2-russian-diplomats-citing-evidence-of-a-contract-murder-in-berli" data-metrics='{"action" : "Click Story 16"}'>
#                 <h3 class="title">Germany Expels 2 Russian Diplomats, Citing Evidence Of A Contract Murder In Berlin</h3>
#             </a>
#
#
#             <a href="https://www.npr.org/2019/12/04/784693025/germany-expels-2-russian-diplomats-citing-evidence-of-a-contract-murder-in-berli" data-metrics='{"action" : "Click Story 16"}'>
#                 <p class="teaser">German prosecutors say they've uncovered evidence that seems to link the suspected gunman to the Russian government. They also say the same man was wanted for a similar killing in Moscow.</p>
#             </a>
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
#       <article class="hp-item volume-low post-type-standard has-image "  id="story784706473"  >
#
#
#
#     <div class="story-wrap">
#
#         <figure class="thumb-image">
#             <div class="bucketwrap homeThumb">
#                 <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2019/12/04/784706473/evgeny-pobozhiy-russian-prodigy-wins-international-jazz-guitar-competition" data-metrics='{"action":"Click Story 17"}' >
#         <img src="https://media.npr.org/assets/img/2019/12/04/108a2209_wide-66371fbd076b07d415d1fe85de372ff3da2e5639-s400-c15.jpg" data-original="https://media.npr.org/assets/img/2019/12/04/108a2209_wide-66371fbd076b07d415d1fe85de372ff3da2e5639-s400.jpg" class="img lazyOnLoad"  alt="Evgeny Pobozhiy, Russian Prodigy, Wins International Jazz Guitar Competition" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#             <p>
#                 Evgeny Pobozhiy, winner of the Herbie Hancock International Jazz Guitar Competition, performing at the Kennedy Center on Dec. 3, 2019.
#
#                 <b class="credit" aria-label="Image credit">
#
#                     Steve Mundinger/Courtesy of the Hancock Institute
#
#                 </b>
#                 <b class="hide-caption"><b>hide caption</b></b>
#             </p>
#         </div>
#
#
#             <b class="toggle-caption"><b>toggle caption</b></b>
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         Steve Mundinger/Courtesy of the Hancock Institute
#
#     </span>
# </div>
#
#             </div>
#         </figure>
#
#
#         <div class="story-text">
#                 <div class="slug-wrap">
#
#                     <h2 class="slug">
#                         <a href="https://www.npr.org/sections/music-news/" data-metrics='{"action":"Click Slug"}'>
#                         Music News
#                         </a>
#                     </h2>
#                 </div>
#             <a href="https://www.npr.org/2019/12/04/784706473/evgeny-pobozhiy-russian-prodigy-wins-international-jazz-guitar-competition" data-metrics='{"action" : "Click Story 17"}'>
#                 <h3 class="title">Evgeny Pobozhiy, Russian Prodigy, Wins International Jazz Guitar Competition</h3>
#             </a>
#
#
#             <a href="https://www.npr.org/2019/12/04/784706473/evgeny-pobozhiy-russian-prodigy-wins-international-jazz-guitar-competition" data-metrics='{"action" : "Click Story 17"}'>
#                 <p class="teaser">The guitarist, who hails from a small town on the edge of the West Siberian Plain, competed against two Americans for one of, if not the, most prestigious prizes available to younger jazz artists.</p>
#             </a>
#         </div> <!-- /.story-text -->
#     </div> <!-- /.story-wrap -->
# </article>
#       <section class="attachment-group">
#   <article class="hp-item volume-high post-type-standard has-attachment has-image "  id="story782164555"  >
#
#
#
#
#         <div class="story-wrap">
#
#
#             <figure class="head-image">
#                 <div class="bucketwrap homeLarge">
#                     <div class="imagewrap" data-crop-type="wide">
#     <a href="https://www.npr.org/2019/12/03/782164555/nprs-book-concierge-our-guide-to-2019-s-great-reads" data-metrics='{"action":"Click Story 18"}' >
#         <img src="https://media.npr.org/assets/img/2019/12/03/bookconcierge2019_wide-64ffbb7429931cfb5f42715b6998211a8e94f80d-s900-c15.jpg" data-original="https://media.npr.org/assets/img/2019/12/03/bookconcierge2019_wide-64ffbb7429931cfb5f42715b6998211a8e94f80d-s900.jpg" class="img lazyOnLoad"  alt="NPR's Favorite Books Of 2019: The Book Concierge Is Back With 350+ Great Reads" />
#     </a>
# </div>
# <div class="credit-caption">
#     <div class="caption-wrap">
#         <div class="caption" aria-label="Image caption">
#         </div>
#
#
#     </div>
#
#     <span class="credit" aria-label="Image credit">
#
#         NPR
#
#     </span>
# </div>
#
#                 </div>
#             </figure>
#
#
#             <div class="story-text-wrap">
#                 <div class="story-text">
#                         <div class="slug-wrap">
#
#                                 <h2 class="slug">
#                                     <a href="https://www.npr.org/books/" data-metrics='{"action":"Click Slug"}'>
#                                     Books
#                                     </a>
#                                 </h2>
#                         </div>
#                     <a href="https://www.npr.org/2019/12/03/782164555/nprs-book-concierge-our-guide-to-2019-s-great-reads" data-metrics='{"action" : "Click Story 18"}'>
#                         <h3 class="title">NPR's Favorite Books Of 2019: The Book Concierge Is Back With 350+ Great Reads</h3>
#                     </a>
#
#
#                     <a href="https://www.npr.org/2019/12/03/782164555/nprs-book-concierge-our-guide-to-2019-s-great-reads" data-metrics='{"action" : "Click Story 18"}'>
#                         <p class="teaser">Explore seven years of recommendations all in one place: Here are more than 2,000 titles, hand-picked by NPR staff and trusted critics â with handy filters to help you find the perfect book!</p>
#                     </a>
#                 </div> <!-- /.story-text -->
#
#             </div> <!-- /.story-text-wrap -->
#         </div> <!-- /.story-wrap -->
#
# </article>
# <article class="hp-item attachment volume-low">
#     <a class="story-wrap" href="https://www.npr.org/2019/11/21/781673493/how-to-read-more-books" data-metrics='{"action" : "Click Attached Story 18"}'>
#         <div class="story-text">
#             <h3 class="title">From Life Kit: How To Read More Books</h3>
#         </div>
#     </a>
# </article>
#
# </section>
#       <div id="hp-more-list">
#                </div>
#
# <!-- END ID="HP-MORE-LIST" -->
#    </div>
#
# <!-- END CLASS="STORIES-WRAP STORIES-WRAP-TWO" DATA-METRICS-CATEGORY="CURATED LIST" -->
#    <div id="hp-more" data-metrics-all>
#             <div class="hp-label">
#          more from
#       </div>
#       <ul>
#                   <li><a href="/sections/news/" class="more-button option" data-metrics-category="Curated List" data-metrics-action="More Stories" data-metrics-label="news"><b>news</b></a></li>
#          <li><a href="/sections/arts/" class="more-button option" data-metrics-category="Curated List" data-metrics-action="More Stories" data-metrics-label="arts & life"><b>arts & life</b></a></li>
#          <li><a href="/music/" class="more-button option" data-metrics-category="Curated List" data-metrics-action="More Stories" data-metrics-label="music"><b>music</b></a></li>
#       </ul>
#       <div class='hp-item more-card'>
#                </div>
#    </div>
#
# <!-- END ID="HP-MORE" DATA-METRICS-ALL -->
# </div>
#
# <!-- END ID="CONTENTWRAP" -->
# <footer id="npr-footer" class="npr-footer" role="contentinfo" aria-label="NPR footer"><div class="npr-footer__content" data-metrics-category="Global Footer" data-metrics-label="Footer">
#     <div class="npr-footer__module-group">
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">Read &amp; Listen</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/" data-metrics-action="Click Homepage">Home</a></li>
#                 <li class="npr-footer__item"><a href="/sections/news/" data-metrics-action="Click News">News</a></li>
#                 <li class="npr-footer__item"><a href="/sections/arts/" data-metrics-action="Click Arts &amp; Life">Arts &amp; Life</a></li>
#                 <li class="npr-footer__item"><a href="/music/" data-metrics-action="Click Music">Music</a></li>
#                 <li class="npr-footer__item"><a href="/podcasts/" data-metrics-action="Click Podcasts">Podcasts</a></li>
#                 <li class="npr-footer__item"><a href="/programs/" data-metrics-action="Click Programs">Programs</a></li>
#             </ul>
#         </div>
#
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">Connect</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/newsletters/" data-metrics-action="Click Newsletters">Newsletters</a></li>
#                 <li class="npr-footer__item"><a href="https://www.facebook.com/NPR/" data-metrics-action="Click Facebook">Facebook</a></li>
#                 <li class="npr-footer__item"><a href="https://twitter.com/NPR" data-metrics-action="Click Twitter">Twitter</a></li>
#                 <li class="npr-footer__item"><a href="https://www.instagram.com/npr/" data-metrics-action="Click Instagram">Instagram</a></li>
#                 <li class="npr-footer__item"><a href="https://www.npr.org/contact" data-metrics-action="Click Contact">Contact</a></li>
#                 <li class="npr-footer__item"><a href="https://help.npr.org" data-metrics-action="Click Help">Help</a></li>
#             </ul>
#         </div>
#
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">About NPR</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/about/" data-metrics-action="Click Overview">Overview</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/178660742/public-radio-finances" data-metrics-action="Click Finances">Finances</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/179803822/people-at-npr" data-metrics-action="Click People">People</a></li>
#                 <li class="npr-footer__item"><a href="/press/" data-metrics-action="Click Press">Press</a></li>
#                 <li class="npr-footer__item"><a href="/sections/publiceditor/" data-metrics-action="Click Public Editor">Public Editor</a></li>
#                 <li class="npr-footer__item"><a href="/corrections/" data-metrics-action="Click Corrections">Corrections</a></li>
#             </ul>
#         </div>
#
#         <div class="npr-footer__module">
#             <h6 class="npr-footer__header">Get Involved</h6>
#
#             <ul>
#                 <li class="npr-footer__item"><a href="/support/" data-metrics-action="Click Support Public Radio">Support Public Radio</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/186948703/corporate-sponsorship" data-metrics-action="Click Sponsor NPR">Sponsor NPR</a></li>
#                 <li class="npr-footer__item"><a href="/careers/" data-metrics-action="Click NPR Careers">NPR Careers</a></li>
#                 <li class="npr-footer__item"><a href="https://shop.npr.org/" data-metrics-action="Click NPR Shop">NPR Shop</a></li>
#                 <li class="npr-footer__item"><a href="https://www.nprpresents.org" data-metrics-action="Click NPR Events">NPR Events</a></li>
#                 <li class="npr-footer__item"><a href="/about-npr/177066727/visit-npr" data-metrics-action="Click Visit NPR">Visit NPR</a></li>
#             </ul>
#         </div>
#     </div>
#
#     <div class="npr-footer__module npr-footer__module--secondary">
#         <ul>
#             <li class="npr-footer__item"><a href="/about-npr/179876898/terms-of-use" data-metrics-action="Click Terms of Use">Terms of Use</a></li>
#             <li class="npr-footer__item"><a href="/about-npr/179878450/privacy-policy" data-metrics-action="Click Privacy">Privacy</a></li>
#             <li class="npr-footer__item"><a href="/about-npr/179878450/privacy-policy#yourchoices" data-metrics-action="Click Your Privacy Choices">Your Privacy Choices</a></li>
#             <li class="npr-footer__item"><a href="https://text.npr.org/" data-metrics-action="Click Text Only">Text Only</a></li>
#             <li class="npr-footer__item"><span class="copy-year"></span></li>
#         </ul>
#     </div>
# </div></footer><div id="global-stickybar-mount" class="global-stickybar-mount">
#    </div>
# </section>   <div id="main-sidebar">
#             <aside id="ad-standard-wrap" aria-label="advertisement">
#
#
#     <div id="ad-standard-homepage" class="ad-standard" data-ad-config='{"network":"\/6735\/","site":{"default":"n6735.NPR","mobile":"n6735.NPRMOBILE"},"zone":"homepage","targets":{"testserver":"false","isPodcastEpisode":"false","storyId":"1002"},"location":"standard","deferred":false,"isBetweenContent":false,"isAggSponsorship":false,"borderClass":""}'></div>
#     <p class="left">NPR thanks our sponsors</p><p class="right"><a href="/about-npr/186948703/corporate-sponsorship">Become an NPR sponsor</a></p>
#
# </aside>
#    </div>
#
# <!-- END ID="MAIN-SIDEBAR" -->
# </div>
#
# <!-- END ID="WRAPPER" -->
# <section id="global-modal-mount"></section>
# <!-- END ID="GLOBAL-MODAL-MOUNT" -->
# <script type="text/javascript">
#    (function () {
#     var loadPageJs = function () { webpackJsonp([76,25],{0:function(n,t,c){n.exports=c(1972)},1972:function(n,t,c){"use strict";c.p=NPR.serverVars.webpackPublicPath,function(){var n=2,t=function(){--n<1&&function(n){c(50),c(2364),c(2365),c(280),c(441),c(414),c(867),c(627),c(1546),c(389)}(c)}.bind(this);c.e(0,t),c.e(7,t)}.call(this)}}); };
#     if (document.readyState === 'complete') {
#         loadPageJs();
#     } else {
#         window.addEventListener('load', function load() {
#             window.removeEventListener('load', load, false);
#             loadPageJs();
#         });
#     }
# })();
# </script>
# </main><noscript><iframe><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1621557368158968&ev=PageView&noscript=1" /></iframe></noscript><script type='text/javascript'>
#     var _sf_async_config = _sf_async_config || {};
#     /** CONFIGURATION START **/
#     _sf_async_config.uid = '18888';
#     _sf_async_config.domain = NPR.ServerConstants.cbHost;
#     _sf_async_config.useCanonical = true;
#
#     /** CONFIGURATION END **/
#     (function() {
#         function loadChartbeat() {
#             // Wait until the metric for chartbeat have been setup
#             // in templates/javascript/metrics/chartbeat.js
#             if( !!NPR.ChartbeatLoaded) {
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#                 e.setAttribute('src', 'https://static.chartbeat.com/js/chartbeat.js');
#                 document.body.appendChild(e);
#             } else {
#                 setTimeout(loadChartbeat, 1000);
#             }
#         }
#
#         var oldonload = window.onload;
#         window.onload = (typeof window.onload != 'function') ?
#                 loadChartbeat : function() {
#             oldonload();
#             window._sf_endpt = (new Date()).getTime();
#             loadChartbeat();
#         };
#     })();
# </script></body></html>

# %%
url = 'https://site-to-scrape.glitch.me'
headers = {'User-Agent' : 'Codeup Data Science Student'}
response = get(url,headers = headers)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Site to Scrape!</title>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <!-- import the webpage's stylesheet -->
#     <link rel="stylesheet" href="/style.css">
#
#     <!-- import the webpage's javascript file -->
#     <script src="/script.js" defer></script>
#   </head>
#   <body>
#     <header>
#       <h1>This is the header!</h1>
#       <hr>
#     </header>
#
#     <main>
#       <div>
#         <h1 class="first">
#         This is the main
#         </h1>
#         <h2>
#           This is an h2 of main
#         </h2>
#         <h3>
#           H3 inside of first div inside of main
#         </h3>
#       </div>
#       <div>
#         <h3 class="first">
#           H3 inside of second div inside of main.
#         </h3>
#         <p>
#           Here's some text content for us to scrape! 👽
#         </p>
#         <p>
#           Here's another paragraph of content! ☠️
#         </p>
#         <a href="https://ryanorsinger.com">Click here to visit my homepage</a>
#       </div>
#     </main>
#
#     <footer>
#       <h1>This is the footer</h1>
#       <img src="https://traffic-analytics.glitch.me/counter.png?fallback=MY_WEBSITE&color=black" alt="" style="vertical-align: bottom;" aria-hidden="true">
#     </footer>
#
#   </body>
# </html>

# %%
url = 'https://codeup.com/codeups-data-science-career-accelerator-is-here/'
headers = {'User-Agent': 'Codeup Ada Data Science'} # codeup.com doesn't like our default user-agent
response = get(url, headers=headers)

# %%
from requests import get
from bs4 import BeautifulSoup
import os

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
article = soup.find('div', class_='mk-single-content')
article.text
# Out:
# '\nThe rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America.\nData Science is a method of providing actionable intelligence from data.\xa0The data revolution has hit San Antonio,\xa0resulting in an explosion in Data Scientist positions\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\xa0We built a program to specifically meet the growing demands of this industry.\nOur program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Students will work with real data sets, realistic problems, and the entire data science pipeline from collection to deployment. They will receive professional development training in resume writing, interviewing, and continuing education to prepare for a smooth transition to the workforce.\nWe focus on applied data science for immediate impact and ROI in a business, which is how we can back it all up with a 6 month tuition refund guarantee – just like our existing Web Dev program. We’re focusing on Data Science with Python, SQL, and ML, covered in\xa014 modules: 1) Fundamentals; 2) Applied statistics; 3) SQL; 4) Python; 5) Supervised machine learning – regression; 6) Supervised machine learning – classification; 7) Unsupervised machine learning – clustering; 8) Time series analysis; 9) Anomaly detection; 10) Natural language processing; 11) Distributed machine learning; 12) Advanced topics (deep learning, NoSQL, cloud deployment, etc.); 13) Storytelling with data; and 14) Domain expertise development.\nApplications are now open\xa0for Codeup’s first Data Science cohort, which will start class on February 4, 2019. Hurry – there are only 25 seats available! To further our mission of cultivating inclusive growth, scholarships will be available to women, minorities, LGBTQIA+ individuals, veterans, first responders, and people relocating to San Antonio.\nIf you want to learn about joining our program or hiring our graduates, email datascience@codeup.com!\n'

# %%
with open('article.txt', 'w') as f:
    f.write(article.text)
